# %% [markdown]
# <a href="https://colab.research.google.com/github/CrabRave4204/KSU-IE/blob/main/SQC_Homework_4_Henry_Walston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('/content/Table 13E.2.csv')
df
# Out:
#     A  B  C  life condition
# 0  -1 -1 -1   221       (1)
# 1  -1 -1 -1   311       (1)
# 2   1 -1 -1   325         a
# 3   1 -1 -1   435         a
# 4  -1  1 -1   354         b
# 5  -1  1 -1   348         b
# 6   1  1 -1   552        ab
# 7   1  1 -1   472        ab
# 8  -1 -1  1   440         c
# 9  -1 -1  1   453         c
# 10  1 -1  1   406        ac
# 11  1 -1  1   377        ac
# 12 -1  1  1   605        bc
# 13 -1  1  1   500        bc
# 14  1  1  1   392       abc
# 15  1  1  1   419       abc

# %%
import statsmodels.formula.api as sm


model = sm.ols('life ~ A + B + C + A:B + A:C + B:C + A:B:C', data=df)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   life   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.726
# Method:                 Least Squares   F-statistic:                     6.665
# Date:                Fri, 11 Oct 2024   Prob (F-statistic):            0.00790
# Time:                        11:00:42   Log-Likelihood:                -79.629
# No. Observations:                  16   AIC:                             175.3
# Df Residuals:                       8   BIC:                             181.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    413.1250     12.406     33.301      0.000     384.517     441.733
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/Table 13E.3.csv')
df
# Out:
#     A  B  C  D  Taste Condition
# 0  -1 -1 -1 -1    188       (1)
# 1  -1 -1 -1 -1    195       (1)
# 2   1 -1 -1 -1    172         a
# 3   1 -1 -1 -1    180         a
# 4  -1  1 -1 -1    179         b
# 5  -1  1 -1 -1    187         b
# 6   1  1 -1 -1    185        ab
# 7   1  1 -1 -1    178        ab
# 8  -1 -1  1 -1    175         c
# 9  -1 -1  1 -1    180         c
# 10  1 -1  1 -1    183        ac
# 11  1 -1  1 -1    178        ac
# 12 -1  1  1 -1    190        bc
# 13 -1  1  1 -1    180        bc
# 14  1  1  1 -1    175       abc
# 15  1  1  1 -1    168       abc
# 16 -1 -1 -1  1    200         d
# 17 -1 -1 -1  1    193         d
# 18  1 -1 -1  1    170        ad
# 19  1 -1 -1  1    178        ad
# 20 -1  1 -1  1    189        bd
# 21 -1  1 -1  1    181        bd
# 22  1  1 -1  1    183       abd
# 23  1  1 -1  1    188       abd
# 24 -1 -1  1  1    201        cd
# 25 -1 -1  1  1    188        cd
# 26  1 -1  1  1    181       acd
# 27  1 -1  1  1    173       acd
# ...

# %%
import statsmodels.formula.api as sm


model = sm.ols('Taste ~ A + B + C + D + A:B + A:C + B:C + A:B:C + A:D + B:D + C:D + A:B:D + A:C:D + B:C:D + A:B:C:D', data=df)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Taste   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     3.471
# Date:                Fri, 11 Oct 2024   Prob (F-statistic):            0.00917
# Time:                        11:01:57   Log-Likelihood:                -88.141
# No. Observations:                  32   AIC:                             208.3
# Df Residuals:                      16   BIC:                             231.7
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    182.7813      0.950    192.314      0.000     180.766     184.796
# ...
